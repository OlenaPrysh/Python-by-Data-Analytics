# %%
print ('Hello world!')
# Out:
# Hello world!

# %%
120 + 30
# Out:
# 150

# %% [markdown]
# # Розділ 1

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9AAE-3467
#
#  Directory of C:\Users\lena1\anaconda_projects\c1c56180-8d3e-444c-9f19-1789e86293b7
#
# 11/02/2025  08:16 PM    <DIR>          .
# 11/02/2025  07:55 PM    <DIR>          ..
# 11/02/2025  07:55 PM    <DIR>          .ipynb_checkpoints
# 11/02/2025  08:16 PM             1,806 My first Notebook.ipynb
#                1 File(s)          1,806 bytes
#                3 Dir(s)  384,039,849,984 bytes free

# %%
# !cd
# Out:
# C:\Users\lena1\anaconda_projects\c1c56180-8d3e-444c-9f19-1789e86293b7

# %%
import time

for i in range(10):
    print(i)
    time.sleep(30)
# Out:
# 0
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       3 for i in range(10):
#       4     print(i)
# ----> 5     time.sleep(30)
#
# KeyboardInterrupt:

# %%
my_list = [1, 2, 3, 4]

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# в мене є список
# * Один
#   - підсписок
#     - це
#   - інший піпсписок
#     - то
#     - і ще то
# * Два
#   - підсписок

# %%
[x**2 for x in range(-10, 11)]
# Out:
# [100, 81, 64, 49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
s = 'Hello world!'

# %%
1+1
print(2+2)
print(3+3)
s
# Out:
# 4
# 6
# 'Hello world!'

# %%
print(s)
# Out:
# Hello world!

# %%
a = 'Hello everyone!'

# %%
a
# Out:
# 'Hello everyone!'

# %%
a.lower()
# Out:
# 'hello everyone!'

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot(range(10))

# %%
import numpy as np

# %%
plt.plot(np.sin(range(20)));

# %% [markdown]
# ## 1.3 Розділ 2

# %%
a = 1
b = 2
a + b
# Out:
# 3
